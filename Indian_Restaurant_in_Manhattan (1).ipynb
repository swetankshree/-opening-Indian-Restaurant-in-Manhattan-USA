# %% [markdown]
# # Indian Restaurant in Manhattan, USA

# %% [markdown]
# **Opening a Indian Restaurant in Manhattan,New York**

# %% [markdown]
# *  Build a dataframe of neighborhoods in New York, USA by using the data set availabale on https://geo.nyu.edu/catalog/nyu_2451_34572
# *   Get the geographical coordinates of the neighborhoods
# *   Obtain Manhattan Boroughs using the geocode
# *   Obtain the venue data for the neighborhoods from Foursquare AP
# *   Explore and cluster the neighborhoods
# *   Select the best cluster to open a new Indian Restaurant

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
! pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.7/dist-packages (1.17.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.7/dist-packages (from geopy) (1.50)

# %%
from geopy.geocoders import Nominatim
import urllib.request
import json
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
from pandas.io.json import json_normalize
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.colors as colors
# %matplotlib inline
from sklearn.cluster import KMeans

# %%
! pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.7/dist-packages (0.8.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from folium) (2.11.3)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from folium) (0.4.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from folium) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from folium) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from folium) (1.19.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->folium) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2020.12.5)

# %%
import folium

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# **Downloading the Dataset**

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')

with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)
# Out:
# Data downloaded!

# %% [markdown]
# **Exploring the dataset**

# %% [markdown]
# Download and Explore Dataset Neighborhood has a total of 5 boroughs and 306 neighborhoods. In order to segement the neighborhoods and explore them, we will essentially need a dataset that contains the 5 boroughs and the neighborhoods that exist in each borough as well as the the latitude and logitude coordinates of each neighborhood

# %%
neighborhoods_data = newyork_data['features']
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)
print(neighborhoods_data)
# Out:
# [{'type': 'Feature', 'id': 'nyu_2451_34572.1', 'geometry': {'type': 'Point', 'coordinates': [-73.84720052054902, 40.89470517661]}, 'geometry_name': 'geom', 'properties': {'name': 'Wakefield', 'stacked': 1, 'annoline1': 'Wakefield', 'annoline2': None, 'annoline3': None, 'annoangle': 0.0, 'borough': 'Bronx', 'bbox': [-73.84720052054902, 40.89470517661, -73.84720052054902, 40.89470517661]}}, {'type': 'Feature', 'id': 'nyu_2451_34572.2', 'geometry': {'type': 'Point', 'coordinates': [-73.82993910812398, 40.87429419303012]}, 'geometry_name': 'geom', 'properties': {'name': 'Co-op City', 'stacked': 2, 'annoline1': 'Co-op', 'annoline2': 'City', 'annoline3': None, 'annoangle': 0.0, 'borough': 'Bronx', 'bbox': [-73.82993910812398, 40.87429419303012, -73.82993910812398, 40.87429419303012]}}, {'type': 'Feature', 'id': 'nyu_2451_34572.3', 'geometry': {'type': 'Point', 'coordinates': [-73.82780644716412, 40.887555677350775]}, 'geometry_name': 'geom', 'properties': {'name': 'Eastchester', 'stacked': 1, 'annoline1': 'Eastchester', 'annoline2': None, 'annoline3': None, 'annoangle': 0.0, 'borough': 'Bronx', 'bbox': [-73.82780644716412, 40.887555677350775, -73.82780644716412, 40.887555677350775]}}, {'type': 'Feature', 'id': 'nyu_2451_34572.4', 'geometry': {'type': 'Point', 'coordinates': [-73.90564259591682, 40.89543742690383]}, 'geometry_name': 'geom', 'properties': {'name': 'Fieldston', 'stacked': 1, 'annoline1': 'Fieldston', 'annoline2': None, 'annoline3': None, 'annoangle': 0.0, 'borough': 'Bronx', 'bbox': [-73.90564259591682, 40.89543742690383, -73.90564259591682, 40.89543742690383]}}, {'type': 'Feature', 'id': 'nyu_2451_34572.5', 'geometry': {'type': 'Point', 'coordinates': [-73.9125854610857, 40.890834493891305]}, 'geometry_name': 'geom', 'properties': {'name': 'Riverdale', 'stacked': 1, 'annoline1': 'Riverdale', 'annoline2': None, 'annoline3': None, 'annoangle': 0.0, 'borough': 'Bronx', 'bbox': [-73.9125854610857, 40.890834493891305, -73.9125854610857, 40.890834493891305]}}, {'type': 'Feature', 'id': 'nyu_2451_34572.6', 'geometry': {'type': 'Point', 'coordinates': [-73.90281798724604, 40.88168737120521]}, 'geometry_name': 'geom', 'properties': {'name': 'Kingsbridge', 'stacked': 1, 'annoline1': 'Kingsbridge', 'annoline2': None, 'annoline3': None, 'annoangle': 0.0, 'borough': 'Bronx', 'bbox': [-73.90281798724604, 40.88168737120521, -73.90281798724604, 40.88168737120521]}}, {'type': 'Feature', 'id': 'nyu_2451_34572.7', 'geometry': {'type': 'Point', 'coordinates': [-73.91065965862981, 40.87655077879964]}, 'geometry_name': 'geom', 'properties': {'name': 'Marble Hill', 'stacked': 2, 'annoline1': 'Marble', 'annoline2': 'Hill', 'annoline3': None, 'annoangle': 0.0, 'borough': 'Manhattan', 'bbox': [-73.91065965862981, 40.87655077879964, -73.91065965862981, 40.87655077879964]}}, {'type': 'Feature', 'id': 'nyu_2451_34572.8', 'geometry': {'type': 'Point', 'coordinates': [-73.86731496814176, 40.89827261213805]}, 'geometry_name': 'geom', 'properties': {'name': 'Woodlawn', 'stacked': 1, 'annoline1': 'Woodlawn', 'annoline2': None, 'annoline3': None, 'annoangle': 0.0, 'borough': 'Bronx', 'bbox': [-73.86731496814176, 40.89827261213805, -73.86731496814176, 40.89827261213805]}}, {'type': 'Feature', 'id': 'nyu_2451_34572.9', 'geometry': {'type': 'Point', 'coordinates': [-73.8793907395681, 40.87722415599446]}, 'geometry_name': 'geom', 'properties': {'name': 'Norwood', 'stacked': 1, 'annoline1': 'Norwood', 'annoline2': None, 'annoline3': None, 'annoangle': 0.0, 'borough': 'Bronx', 'bbox': [-73.8793907395681, 40.87722415599446, -73.8793907395681, 40.87722415599446]}}, {'type': 'Feature', 'id': 'nyu_2451_34572.10', 'geometry': {'type': 'Point', 'coordinates': [-73.85744642974207, 40.88103887819211]}, 'geometry_name': 'geom', 'properties': {'name': 'Williamsbridge', 'stacked': 1, 'annoline1': 'Williamsbridge', 'annoline2': None, 'annoline3': None, 'annoangle': 0.0, 'borough': 'Bronx', 'bbox': [-73.85744642974207, 40.88103887819211, -73.85744642974207, 40.8810388781 ...

# %%
for data in neighborhoods_data:
    borough = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
print(neighborhoods.head())
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
print(neighborhoods.shape)
# Out:
# (612, 4)

# %% [markdown]
# **Getting dataset for Manhattan**

# %%
manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan'].reset_index(drop=True)
manhattan_data.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude
# 0  Manhattan         Marble Hill  40.876551 -73.910660
# 1  Manhattan           Chinatown  40.715618 -73.994279
# 2  Manhattan  Washington Heights  40.851903 -73.936900
# 3  Manhattan              Inwood  40.867684 -73.921210
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688

# %%
manhattan_data.Neighborhood.unique
# Out:
# <bound method Series.unique of 0             Marble Hill
# 1               Chinatown
# 2      Washington Heights
# 3                  Inwood
# 4        Hamilton Heights
# 5          Manhattanville
# 6          Central Harlem
# 7             East Harlem
# 8         Upper East Side
# 9               Yorkville
# 10             Lenox Hill
# 11       Roosevelt Island
# 12        Upper West Side
# 13         Lincoln Square
# 14                Clinton
# 15                Midtown
# 16            Murray Hill
# 17                Chelsea
# 18      Greenwich Village
# 19           East Village
# 20        Lower East Side
# 21                Tribeca
# 22           Little Italy
# 23                   Soho
# 24           West Village
# 25       Manhattan Valley
# 26    Morningside Heights
# 27               Gramercy
# 28      Battery Park City
# 29     Financial District
# 30          Carnegie Hill
# 31                   Noho
# 32           Civic Center
# 33          Midtown South
# 34           Sutton Place
# 35             Turtle Bay
# 36             Tudor City
# 37        Stuyvesant Town
# 38               Flatiron
# 39           Hudson Yards
# 40            Marble Hill
# 41              Chinatown
# 42     Washington Heights
# 43                 Inwood
# 44       Hamilton Heights
# 45         Manhattanville
# 46         Central Harlem
# 47            East Harlem
# 48        Upper East Side
# 49              Yorkville
# 50             Lenox Hill
# 51       Roosevelt Island
# 52        Upper West Side
# 53         Lincoln Square
# 54                Clinton
# 55                Midtown
# 56            Murray Hill
# 57                Chelsea
# 58      Greenwich Village
# 59           East Village
# 60        Lower East Side
# 61                Tribeca
# 62           Little Italy
# 63                   Soho
# 64           West Village
# 65       Manhattan Valley
# 66    Morningside Heights
# 67               Gramercy
# 68      Battery Park City
# 69     Financial District
# 70          Carnegie Hill
# 71                   Noho
# 72           Civic Center
# 73          Midtown South
# 74           Sutton Place
# 75             Turtle Bay
# 76             Tudor City
# 77        Stuyvesant Town
# 78               Flatiron
# 79           Hudson Yards
# Name: Neighborhood, dtype: object>

# %% [markdown]
# **Use Geopy for location**

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
ny_latitude = location.latitude
ny_longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(ny_latitude, ny_longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %% [markdown]
# **Import Folium**

# %% [markdown]
# Mark the neighborhods of New York on the Folium Map

# %%
import folium
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[ny_latitude, ny_longitude], zoom_start=11.4)

# add markers to map
for lat, lng, borough, neighborhood in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Borough'], manhattan_data['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=5,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_fd9dc1ac218847e4975b3f8e0b947f0f%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fd9dc1ac218847e4975b3f8e0b947f0f%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_fd9dc1ac218847e4975b3f8e0b947f0f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_fd9dc1ac218847e4975b3f8e0b947f0f%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B40.7127281%2C%20-74.0060152%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011.4%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_06e824504c6f4e3a86a2b9613491164a%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%2 ...

# %% [markdown]
# **Use GeoCode to find the coordinate of Manhattan, NY**

# %%
address = 'Manhattan, New York, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
manhat_latitude = location.latitude
manhat_longitude = location.longitude
radius=5000
print('The geograpical coordinate of Manhattan  are {}, {}.'.format(manhat_latitude, manhat_longitude))
# Out:
# The geograpical coordinate of Manhattan  are 40.7896239, -73.9598939.

# %% [markdown]
# **Use the FOURSQUARE API to get Venue**

# %% [markdown]
# Search top 500 Indain Restaurant using the Foursquare API and get the location of the Indian Restaurants within the radius of 5 km

# %%
CLIENT_ID = 'DIQS0ZLMYHDNXPZCKF4RZNQB2BSBCXOY1LBEDGUK2G3VDG3A' # your Foursquare ID
CLIENT_SECRET = 'GNRMVGQGXSE1AWXQNZSXWLFZQ1MXD3B15F4EEZDTFNGB5LY4' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 500
search_query = 'Indian Restaurants'

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, manhat_latitude, manhat_longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=DIQS0ZLMYHDNXPZCKF4RZNQB2BSBCXOY1LBEDGUK2G3VDG3A&client_secret=GNRMVGQGXSE1AWXQNZSXWLFZQ1MXD3B15F4EEZDTFNGB5LY4&ll=40.7896239,-73.9598939&v=20180604&query=Indian Restaurants&radius=5000&limit=500'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60978063c609596796a58882'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fd941735',
#       'name': 'Shopping Mall',
#       'pluralName': 'Shopping Malls',
#       'primary': True,
#       'shortName': 'Mall'}],
#     'hasPerk': False,
#     'id': '5b9f8c9833e118002c53aa87',
#     'location': {'address': '20 Hudson Yards',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 5345,
#      'formattedAddress': ['20 Hudson Yards',
#       'New York, NY 10001',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75368434864726,
#        'lng': -74.00195360183716}],
#      'lat': 40.75368434864726,
#      'lng': -74.00195360183716,
#      'neighborhood': 'Hudson Yards',
#      'postalCode': '10001',
#      'state': 'NY'},
#     'name': 'The Shops & Restaurants at Hudson Yards',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'id': '54541900498ea6ccd0202697',
#       'name': 'Health & Beauty Service',
#       'pluralName': 'Health & Beauty Services',
#       'primary': True,
#       'shortName': 'Health & Beauty'}],
#     'hasPerk': False,
#     'id': '5b17c9f935d3fc002c2c09db',
#     'location': {'address': '1148 5th Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'Suite 1B',
#      'distance': 445,
#      'formattedAddress': ['1148 5th Ave (Suite 1B)',
#       'New York, NY 10128',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78746795654297,
#        'lng': -73.9554443359375}],
#      'lat': 40.78746795654297,
#      'lng': -73.9554443359375,
#      'postalCode': '10128',
#      'state': 'NY'},
#     'name': 'Indian Egg Donors DGA, Inc.',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'primary': True,
#       'shortName': 'Food'}],
#     'hasPerk': False,
#     'id': '4f32a9c119836c91c7eda319',
#     'location': {'address': '338 9th Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 5430,
#      'formattedAddress': ['338 9th Ave',
#       'New York, NY 10001',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7503662109375,
#        'lng': -73.99813842773438}],
#      'lat': 40.7503662109375,
#      'lng': -73.99813842773438,
#      'postalCode': '10001',
#      'state': 'NY'},
#     'name': 'Indian Restaurant',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'delivery': {'id': '1661007',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/indian-summer-239-lenox-ave-new-york/1661007?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1661007'},
#     'hasPerk': False,
#     'id': '5de9508b70ea2300085cfd33',
#     'location': {'address': '239 Malcolm X Blvd',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 2097,
#      'formattedAddress': ['239 Malcolm X Blvd',
#       'New York, NY 10027',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.805885314941406,
#        'lng': -73.94731140136719}],
#      'lat': 40.805885314941406,
#      'lng': -73.94731140136719,
#      'postalCode': '10027',
#      'state': 'NY'},
#     'name': 'Indian Summer',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'primary': True,
#       'shortName': 'Food Truck'}],
#     'hasPerk': False,
#     'id': '4c6ec437c52437042cf42beb',
#     'location': {'address': '53rd street',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'Park avenue',
#      'distance': 3514,
#      'formattedAddress': ['53rd street (Park avenue)',
#       'New York, NY 10022',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75946861543554,
#        'lng': -73.97225608333729}],
#      'lat': 40.75946861543554,
#      'lng': -73.97225608333729,
#      'postalCode': '10022',
#      'state': 'NY'},
#     'name': 'Indian fast food cart',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'delivery': {'id': '321971',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/mughlai-indian-cuisine-1724-2nd-ave-new-york/321971?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=321971'},
#     'hasPerk': False,
#     'id': '56ed855a498ef3bb022352c3',
#     'location': {'address': '1724 2nd Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': '89th & 90th St',
#      'distance': 1335,
#      'formattedAddress': ['1724 2nd Ave (89th & 90th St)',
#       'New York, NY 10128',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78020580283837,
#        'lng': -73.95008785684102}],
#      'lat': 40.78020580283837,
#      'lng': -73.95008785684102,
#      'postalCode': '10128',
#      'state': 'NY'},
#     'name': 'Mughlai Indian Cuisine',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'id': '545419b1498ea6ccd0202f58',
#       'name': 'Home Service',
#       'pluralName': 'Home Services & Repairs',
#       'primary': True,
#       'shortName': 'Home Services'}],
#     'hasPerk': False,
#     'id': '5b161bd80a08ab002cad2b58',
#     'location': {'address': '306 E 61st St 7f',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 3090,
#      'formattedAddress': ['306 E 61st St 7f',
#       'New York, NY 10065',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76208101161184,
#        'lng': -73.96454215049744}],
#      'lat': 40.76208101161184,
#      'lng': -73.96454215049744,
#      'postalCode': '10065',
#      'state': 'NY'},
#     'name': 'Indian Rugs',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '50c270d0e4b070f4c1797392',
#     'location': {'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 2584,
#      'formattedAddress': ['New York, NY 10031', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.812110750460555,
#        'lng': -73.95227022435299}],
#      'lat': 40.812110750460555,
#      'lng': -73.95227022435299,
#      'postalCode': '10031',
#      'state': 'NY'},
#     'name': 'indian Temple',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sculpture_',
#        'suffix': '.png'},
#       'id': '52e81612bcbc57f1066b79ed',
#       'name': 'Outdoor Sculpture',
#       'pluralName': 'Outdoor Sculptures',
#       'primary': True,
#       'shortName': 'Outdoor Sculpture'}],
#     'hasPerk': False,
#     'id': '4e92ee8a6c25b073b7e18bc8',
#     'location': {'address': 'Central Park Dr',
#      'cc': 'US',
#      'country': 'United States',
#      'distance': 2424,
#      'formattedAddress': ['Central Park Dr', 'New York', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.77037242176973,
#        'lng': -73.97335231834764}],
#      'lat': 40.77037242176973,
#      'lng': -73.97335231834764,
#      'state': 'New York'},
#     'name': 'The Indian Hunter',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'delivery': {'id': '68348',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/indian-tanpura-564-amsterdam-ave-new-york/68348?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=68348'},
#     'hasPerk': False,
#     'id': '4adb9df6f964a5206d2921e3',
#     'location': {'address': '564 Amsterdam Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': '87th st',
#      'distance': 1229,
#      'formattedAddress': ['564 Amsterdam Ave (87th st)',
#       'New York, NY 10024',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.788514795983616,
#        'lng': -73.97440482783306}],
#      'lat': 40.788514795983616,
#      'lng': -73.97440482783306,
#      'postalCode': '10024',
#      'state': 'NY'},
#     'name': 'Indian Tanpura',
#     'referralId': 'v-1620541539'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4e188274fa7619464591b952',
#     'location': {'cc': 'US',
#      'city': 'Amagansett',
#      'country': 'United States',
#      'distance': 3376,
#      'formattedAddress': ['Amagansett, NY', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7676684,
#        'lng': -73.9875354}],
#      'lat': 40.7676684,
#      'lng': -73.9875354,
#      'state': 'NY'},
#     'name': 'Indian Wells Beach',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'primary': True,
#       'shortName': 'Office'}],
#     'hasPerk': False,
#     'id': '504e003c7ab4e96db7bc813b',
#     'location': {'address': '590 Madison Ave Fl 18',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'at 57th St.',
#      'distance': 3239,
#      'formattedAddress': ['590 Madison Ave Fl 18 (at 57th St.)',
#       'New York, NY 10022',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.762194779905705,
#        'lng': -73.97272825241089}],
#      'lat': 40.762194779905705,
#      'lng': -73.97272825241089,
#      'postalCode': '10022',
#      'state': 'NY'},
#     'name': 'Indian Country Today',
#     'referralId': 'v-1620541539'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4e0e3cb1aeb7a5b33ee81274',
#     'location': {'address': '316 E 53rd St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 3719,
#      'formattedAddress': ['316 E 53rd St',
#       'New York, NY 10022',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.756593,
#        'lng': -73.966561}],
#      'lat': 40.756593,
#      'lng': -73.966561,
#      'postalCode': '10022',
#      'state': 'NY'},
#     'name': 'Indian Passport Services',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '545eb9de498ed803ac5569c4',
#     'location': {'address': '2036 2nd Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': '105 Street',
#      'distance': 1440,
#      'formattedAddress': ['2036 2nd Ave (105 Street)',
#       'New York, NY 10029',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.789675,
#        'lng': -73.942797},
#       {'label': 'entrance', 'lat': 40.789715, 'lng': -73.942889}],
#      'lat': 40.789675,
#      'lng': -73.942797,
#      'postalCode': '10029',
#      'state': 'NY'},
#     'name': 'Spice Hut Indian Restaurant',
#     'referralId': 'v-1620541539',
#     'venuePage': {'id': '374556954'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'primary': True,
#       'shortName': 'Coworking Space'}],
#     'hasPerk': False,
#     'id': '4c17971f368220a179963657',
#     'location': {'address': '466 Lexington Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 4206,
#      'formattedAddress': ['466 Lexington Ave',
#       'New York, NY 10017',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.753682,
#        'lng': -73.975296}],
#      'lat': 40.753682,
#      'lng': -73.975296,
#      'postalCode': '10017',
#      'state': 'NY'},
#     'name': 'Indian Proverb',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '50c26f82e4b085c8e30b4416',
#     'location': {'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 4216,
#      'formattedAddress': ['New York, NY 10031', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.82476971798691,
#        'lng': -73.94124325197386}],
#      'lat': 40.82476971798691,
#      'lng': -73.94124325197386,
#      'postalCode': '10031',
#      'state': 'NY'},
#     'name': 'Indian place',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4b0ad7f1f964a520be2823e3',
#     'location': {'address': '48 W 48th St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 3922,
#      'formattedAddress': ['48 W 48th St',
#       'New York, NY 10036',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75800704956055,
#        'lng': -73.9804458618164}],
#      'lat': 40.75800704956055,
#      'lng': -73.9804458618164,
#      'postalCode': '10036',
#      'state': 'NY'},
#     'name': 'Indian Express - Midtown',
#     'referralId': 'v-1620541539'},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4e13a13d18a8b99f10a926fc',
#     'location': {'cc': 'US',
#      'country': 'United States',
#      'distance': 5052,
#      'formattedAddress': ['New York', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.754689,
#        'lng': -73.998162}],
#      'lat': 40.754689,
#      'lng': -73.998162,
#      'state': 'New York'},
#     'name': 'The Indian Hut',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'delivery': {'id': '340349',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/indian-express-301-w-154th-st-unit-1-new-york/340349?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=340349'},
#     'hasPerk': False,
#     'id': '58ea88220319b80a65642c3d',
#     'location': {'address': '301 W 154th St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'btwn Frederick Douglass Blvd & Bradhurst Ave',
#      'distance': 4726,
#      'formattedAddress': ['301 W 154th St (btwn Frederick Douglass Blvd & Bradhurst Ave)',
#       'New York, NY 10039',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.828719,
#        'lng': -73.938004}],
#      'lat': 40.828719,
#      'lng': -73.938004,
#      'postalCode': '10039',
#      'state': 'NY'},
#     'name': 'Indian Express',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '5f80ee5556ef2e7ac8fbcc1f',
#     'location': {'address': '165 E 106th St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 1255,
#      'formattedAddress': ['165 E 106th St',
#       'New York, NY 10029',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.792014,
#        'lng': -73.945332}],
#      'lat': 40.792014,
#      'lng': -73.945332,
#      'postalCode': '10029',
#      'state': 'NY'},
#     'name': 'Om Indian Food',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/jewelry_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d111951735',
#       'name': 'Jewelry Store',
#       'pluralName': 'Jewelry Stores',
#       'primary': True,
#       'shortName': 'Jewelry'}],
#     'hasPerk': False,
#     'id': '4fef264ae4b0f9f20fcf9240',
#     'location': {'cc': 'US',
#      'country': 'United States',
#      'distance': 5381,
#      'formattedAddress': ['New York', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.745618,
#        'lng': -73.98633}],
#      'lat': 40.745618,
#      'lng': -73.98633,
#      'state': 'New York'},
#     'name': 'Indian-African Handicraft & Jewelery',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '581cbe0cb04e9861ebfcb64f',
#     'location': {'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 5018,
#      'formattedAddress': ['New York, NY', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74985,
#        'lng': -73.987908}],
#      'lat': 40.74985,
#      'lng': -73.987908,
#      'state': 'NY'},
#     'name': 'Indian Project - Broadway Bites',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '54135bf5e4b08f3d2429dfdd',
#       'name': 'North Indian Restaurant',
#       'pluralName': 'North Indian Restaurants',
#       'primary': True,
#       'shortName': 'North Indian'}],
#     'delivery': {'id': '2234475',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/indian-accent-123-w-56th-st-new-york/2234475?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2234475'},
#     'hasPerk': False,
#     'id': '56c55e43cd105142e6f95b94',
#     'location': {'address': '123 W 56th St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 3254,
#      'formattedAddress': ['123 W 56th St',
#       'New York, NY 10019',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76412724424148,
#        'lng': -73.97878651245028},
#       {'label': 'entrance', 'lat': 40.764201, 'lng': -73.978653}],
#      'lat': 40.76412724424148,
#      'lng': -73.97878651245028,
#      'postalCode': '10019',
#      'state': 'NY'},
#     'name': 'Indian Accent',
#     'referralId': 'v-1620541539',
#     'venuePage': {'id': '219733048'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'delivery': {'id': '319303',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/polash-indian-restaurant-2179-3rd-ave-new-york/319303?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=319303'},
#     'hasPerk': False,
#     'id': '4a60aa67f964a520f9c01fe3',
#     'location': {'address': '2179 3rd Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'at 119th St.',
#      'distance': 2108,
#      'formattedAddress': ['2179 3rd Ave (at 119th St.)',
#       'New York, NY 10035',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79974477464853,
#        'lng': -73.9387466714612},
#       {'label': 'entrance', 'lat': 40.799653, 'lng': -73.938567}],
#      'lat': 40.79974477464853,
#      'lng': -73.9387466714612,
#      'postalCode': '10035',
#      'state': 'NY'},
#     'name': 'Polash Indian restaurant',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'delivery': {'id': '424047',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/anand-indian-cuisine-304-e-78th-st-new-york/424047?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=424047'},
#     'hasPerk': False,
#     'id': '594f13461987ec28dc1e4dff',
#     'location': {'address': '304 E 78th St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'btwn 1st & 2nd Ave',
#      'distance': 1975,
#      'formattedAddress': ['304 E 78th St (btwn 1st & 2nd Ave)',
#       'New York, NY 10075',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.772261,
#        'lng': -73.955041}],
#      'lat': 40.772261,
#      'lng': -73.955041,
#      'postalCode': '10075',
#      'state': 'NY'},
#     'name': 'Anand Indian Cuisine',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4ca8c25344a8224b3dc61a40',
#     'location': {'address': '283 Columbus Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': '73rd',
#      'distance': 1978,
#      'formattedAddress': ['283 Columbus Ave (73rd)',
#       'New York, NY 10023',
#       'United States'],
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 40.778226,
#        'lng': -73.977992},
#       {'label': 'display',
#        'lat': 40.77830123901367,
#        'lng': -73.97798919677734}],
#      'lat': 40.77830123901367,
#      'lng': -73.97798919677734,
#      'postalCode': '10023',
#      'state': 'NY'},
#     'name': 'Swagatam Indian',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'delivery': {'id': '435222',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/imli-urban-indian-food-1136-1st-ave-new-york/435222?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=435222'},
#     'hasPerk': False,
#     'id': '59d412d2f427de6924145531',
#     'location': {'address': '1136 1st Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 3114,
#      'formattedAddress': ['1136 1st Ave',
#       'New York, NY 10065',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76164627075195,
#        'lng': -73.96012878417969}],
#      'lat': 40.76164627075195,
#      'lng': -73.96012878417969,
#      'postalCode': '10065',
#      'state': 'NY'},
#     'name': 'Imli Urban Indian Food',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '52d84041498e07055c8624b9',
#     'location': {'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 2765,
#      'formattedAddress': ['New York, NY', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.814467,
#        'lng': -73.959276}],
#      'lat': 40.814467,
#      'lng': -73.959276,
#      'state': 'NY'},
#     'name': 'Simply Indian',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4baec265f964a5208fd53be3',
#     'location': {'address': '696 Anderson Ave',
#      'cc': 'US',
#      'city': 'Cliffside Park',
#      'country': 'United States',
#      'distance': 5136,
#      'formattedAddress': ['696 Anderson Ave',
#       'Cliffside Park, NJ 07010',
#       'United States'],
#      'lat': 40.83167976,
#      'lng': -73.98496613,
#      'postalCode': '07010',
#      'state': 'NJ'},
#     'name': 'Jai Ho Indian cuisine',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'primary': True,
#       'shortName': 'American'}],
#     'hasPerk': False,
#     'id': '5f50dff344a698602dd68d91',
#     'location': {'address': '493  Geraldine Lane',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 2397,
#      'formattedAddress': ['493  Geraldine Lane',
#       'New York, NY 10001',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76858174460535,
#        'lng': -73.9659771323204}],
#      'lat': 40.76858174460535,
#      'lng': -73.9659771323204,
#      'postalCode': '10001',
#      'state': 'NY'},
#     'name': 'Junaid Restaurants in Stockton',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'primary': True,
#       'shortName': 'Italian'}],
#     'hasPerk': False,
#     'id': '4a78f65ef964a520b7e61fe3',
#     'location': {'address': '1295 3rd Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'btwn E 74th & E 75th St',
#      'distance': 2034,
#      'formattedAddress': ['1295 3rd Ave (btwn E 74th & E 75th St)',
#       'New York, NY 10021',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.771352488755774,
#        'lng': -73.95968198776245},
#       {'label': 'entrance', 'lat': 40.771192, 'lng': -73.959341}],
#      'lat': 40.771352488755774,
#      'lng': -73.95968198776245,
#      'postalCode': '10021',
#      'state': 'NY'},
#     'name': 'Mezzaluna Restaurants',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'delivery': {'id': '340270',
#      'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'grubhub'},
#      'url': 'https://www.grubhub.com/restaurant/silli-point-indian-fusion-498-anderson-ave-cliffside-park/340270?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=340270'},
#     'hasPerk': False,
#     'id': '57f9bfd6498e44d87e0e4ee9',
#     'location': {'address': '498 Anderson Ave',
#      'cc': 'US',
#      'city': 'Cliffside Park',
#      'country': 'United States',
#      'crossStreet': 'Edgewater Rd',
#      'distance': 4401,
#      'formattedAddress': ['498 Anderson Ave (Edgewater Rd)',
#       'Cliffside Park, NJ 07010',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.82169,
#        'lng': -73.99046}],
#      'lat': 40.82169,
#      'lng': -73.99046,
#      'postalCode': '07010',
#      'state': 'NJ'},
#     'name': 'Silli Point Indian Fusion',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'primary': True,
#       'shortName': 'Food'}],
#     'hasPerk': False,
#     'id': '4f44f6e319836ed00197c781',
#     'location': {'address': '429 Malcolm X Blvd',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 2874,
#      'formattedAddress': ['429 Malcolm X Blvd',
#       'New York, NY 10037',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.811935,
#        'lng': -73.942722}],
#      'lat': 40.811935,
#      'lng': -73.942722,
#      'postalCode': '10037',
#      'state': 'NY'},
#     'name': 'Nuff Niceness Restaurants',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4e4ce1dcbd413c4cc66ced81',
#     'location': {'address': '1007 2nd Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 3675,
#      'formattedAddress': ['1007 2nd Ave',
#       'New York, NY 10022',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.757080078125,
#        'lng': -73.96726989746094}],
#      'lat': 40.757080078125,
#      'lng': -73.96726989746094,
#      'postalCode': '10022',
#      'state': 'NY'},
#     'name': "Jaipur's Indian Cuisine",
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '58854f54326c5a40e0b8c763',
#     'location': {'address': '230 E 58th St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'Between 2nd and 3rd Avenues',
#      'distance': 3316,
#      'formattedAddress': ['230 E 58th St (Between 2nd and 3rd Avenues)',
#       'New York, NY 10022',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.760179,
#        'lng': -73.965884},
#       {'label': 'entrance', 'lat': 40.760305, 'lng': -73.965798}],
#      'lat': 40.760179,
#      'lng': -73.965884,
#      'postalCode': '10022',
#      'state': 'NY'},
#     'name': 'Simon Indian Palace',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'delivery': {'id': '1447437',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/karahi-indian-cuisine-803-9th-ave-new-york/1447437?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1447437'},
#     'hasPerk': False,
#     'id': '52012efe498efd443fa30a06',
#     'location': {'address': '764 9th Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 3699,
#      'formattedAddress': ['764 9th Ave',
#       'New York, NY 10019',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.764156,
#        'lng': -73.988087},
#       {'label': 'entrance', 'lat': 40.764209, 'lng': -73.988212}],
#      'lat': 40.764156,
#      'lng': -73.988087,
#      'postalCode': '10019',
#      'state': 'NY'},
#     'name': 'Basmati Indian Cuisine',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4f439e3819834bc91f57e8eb',
#     'location': {'address': '224 E 53rd St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 3696,
#      'formattedAddress': ['224 E 53rd St',
#       'New York, NY 10022',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.757071999999994,
#        'lng': -73.96852700000001}],
#      'lat': 40.757071999999994,
#      'lng': -73.96852700000001,
#      'postalCode': '10022',
#      'state': 'NY'},
#     'name': "Baluchi's Indian Cuisine",
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '5deaebde8fa13e0007842025',
#     'location': {'address': '803 9th Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'W 53rd St',
#      'distance': 3543,
#      'formattedAddress': ['803 9th Ave (W 53rd St)',
#       'New York, NY 10019',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.765665,
#        'lng': -73.987562},
#       {'label': 'entrance', 'lat': 40.765582, 'lng': -73.987622}],
#      'lat': 40.765665,
#      'lng': -73.987562,
#      'postalCode': '10019',
#      'state': 'NY'},
#     'name': 'Karahi indian',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/halal_',
#        'suffix': '.png'},
#       'id': '52e81612bcbc57f1066b79ff',
#       'name': 'Halal Restaurant',
#       'pluralName': 'Halal Restaurants',
#       'primary': True,
#       'shortName': 'Halal'}],
#     'delivery': {'id': '823219',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/priyas-indian-kitchen-722-10th-ave-new-york/823219?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=823219'},
#     'hasPerk': False,
#     'id': '5a43c6990a08ab1e8a878c63',
#     'location': {'address': '724 10th Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 3889,
#      'formattedAddress': ['724 10th Ave',
#       'New York, NY 10019',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.764311647279904,
#        'lng': -73.99170488119125}],
#      'lat': 40.764311647279904,
#      'lng': -73.99170488119125,
#      'postalCode': '10019',
#      'state': 'NY'},
#     'name': 'The Halal Indian Kitchen',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'delivery': {'id': '1241679',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/indian-nyc-243-w-38th-st-new-york/1241679?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1241679'},
#     'hasPerk': False,
#     'id': '57867106cd104d40b6da106b',
#     'location': {'address': '245 W 38th St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 4693,
#      'formattedAddress': ['245 W 38th St',
#       'New York, NY 10018',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.754293,
#        'lng': -73.990272}],
#      'lat': 40.754293,
#      'lng': -73.990272,
#      'postalCode': '10018',
#      'state': 'NY'},
#     'name': 'Indian Project NYC',
#     'referralId': 'v-1620541539',
#     'venuePage': {'id': '430669898'}},
#    {'categories': [],
#     'hasPerk': False,
#     'id': '4be5ba59cf200f47f3a0133c',
#     'location': {'address': '907',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': '20 / 21 at',
#      'distance': 3316,
#      'formattedAddress': ['907 (20 / 21 at)', 'New York, NY', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76495415857458,
#        'lng': -73.98194979831837}],
#      'lat': 40.76495415857458,
#      'lng': -73.98194979831837,
#      'state': 'NY'},
#     'name': 'Go Burger by BLT restaurants Group',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'primary': True,
#       'shortName': 'Steakhouse'}],
#     'hasPerk': False,
#     'id': '5127ca86e4b0f46f576a637f',
#     'location': {'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 4388,
#      'formattedAddress': ['New York, NY', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.757,
#        'lng': -73.989126}],
#      'lat': 40.757,
#      'lng': -73.989126,
#      'state': 'NY'},
#     'name': 'Dallas BBQ Restaurants',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '52e81612bcbc57f1066b7a34',
#       'name': 'Community Center',
#       'pluralName': 'Community Centers',
#       'primary': True,
#       'shortName': 'Community Center'}],
#     'hasPerk': False,
#     'id': '5e396fe10e15b00007a8743e',
#     'location': {'address': '21-25 44th Ave Ste 102',
#      'cc': 'US',
#      'city': 'Long Island City',
#      'country': 'United States',
#      'distance': 4634,
#      'formattedAddress': ['21-25 44th Ave Ste 102',
#       'Long Island City, NY 11101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.749447,
#        'lng': -73.945496}],
#      'lat': 40.749447,
#      'lng': -73.945496,
#      'postalCode': '11101',
#      'state': 'NY'},
#     'name': 'New York Indian Council',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'delivery': {'id': '2128714',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/tadka-indian-cuisine-13-15-43rd-ave-long-island-city/2128714?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2128714'},
#     'hasPerk': False,
#     'id': '5c8691a8bcbf7a002cbfe19a',
#     'location': {'address': '13-15 43rd Ave',
#      'cc': 'US',
#      'city': 'Queens',
#      'country': 'United States',
#      'distance': 4473,
#      'formattedAddress': ['13-15 43rd Ave',
#       'Queens, NY 11101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.750866,
#        'lng': -73.945854}],
#      'lat': 40.750866,
#      'lng': -73.945854,
#      'postalCode': '11101',
#      'state': 'NY'},
#     'name': 'Tadka Indian Cuisine',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4bf57b3194af2d7f2dc93b72',
#     'location': {'address': '1101 6th Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'Btw W37th St & W38',
#      'distance': 4712,
#      'formattedAddress': ['1101 6th Ave (Btw W37th St & W38)',
#       'New York, NY 10018',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.752126574516296,
#        'lng': -73.98583352565765}],
#      'lat': 40.752126574516296,
#      'lng': -73.98583352565765,
#      'postalCode': '10018',
#      'state': 'NY'},
#     'name': 'Khodiar Indian/Taj Dehli Chat',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'delivery': {'id': '889668',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/deep-indian-kitchen-indikitch-1190-6th-ave-new-york/889668?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=889668'},
#     'hasPerk': False,
#     'id': '5953e40462420b044e8989f4',
#     'location': {'address': '1190 6th Avenue',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 4007,
#      'formattedAddress': ['1190 6th Avenue',
#       'New York, NY 10036',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75768139999999,
#        'lng': -73.9818088}],
#      'lat': 40.75768139999999,
#      'lng': -73.9818088,
#      'neighborhood': 'Midtown East',
#      'postalCode': '10036',
#      'state': 'NY'},
#     'name': 'deep Indian Kitchen',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'primary': True,
#       'shortName': 'Food'}],
#     'hasPerk': False,
#     'id': '4f329e3719836c91c7e94f57',
#     'location': {'address': '30 W 46th St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 4076,
#      'formattedAddress': ['30 W 46th St',
#       'New York, NY 10036',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75653076171875,
#        'lng': -73.9805908203125}],
#      'lat': 40.75653076171875,
#      'lng': -73.9805908203125,
#      'postalCode': '10036',
#      'state': 'NY'},
#     'name': 'Wu Kong Restaurants',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'primary': True,
#       'shortName': 'Food Truck'}],
#     'hasPerk': False,
#     'id': '538b922b498e7ba2b290a647',
#     'location': {'cc': 'US',
#      'city': 'Queens',
#      'country': 'United States',
#      'distance': 4872,
#      'formattedAddress': ['Queens, NY', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.758493,
#        'lng': -73.919255}],
#      'lat': 40.758493,
#      'lng': -73.919255,
#      'state': 'NY'},
#     'name': 'Delicious Indian Food Cart',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'primary': True,
#       'shortName': 'Entertainment'}],
#     'hasPerk': False,
#     'id': '52c8a84b11d29c97ed726ac5',
#     'location': {'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 4300,
#      'formattedAddress': ['New York, NY', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75524053671715,
#        'lng': -73.98314354351062}],
#      'lat': 40.75524053671715,
#      'lng': -73.98314354351062,
#      'state': 'NY'},
#     'name': 'Chhandayan Center for Indian Music',
#     'referralId': 'v-1620541539'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'delivery': {'id': '274919',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/rajs-indian-kitchen-27-18-queens-plz-s-long-island-city/274919?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=274919'},
#     'hasPerk': False,
#     'id': '50a287a7e4b0033f830f06db',
#     'location': {'address': '27-18 Queens Plz S',
#      'cc': 'US',
#      'city': 'Long Island City',
#      'country': 'United States',
#      'distance': 4743,
#      'formattedAddress': ['27-18 Queens Plz S',
#       'Long Island City, NY 11101',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74997632892085,
#        'lng': -73.93926056994543}],
#      'lat': 40.74997632892085,
#      'lng': -73.93926056994543,
#      'postalCode': '11101',
#      'state': 'NY'},
#     'name': "Raj's Indian Kitchen",
#     'referralId': 'v-1620541539'}]}}

# %% [markdown]
# **Convert Dataset to Pandas DataFrame**

# %%
neighborhood_data = results['response']['venues']
# define the dataframe columns
column_names = ["Venue","Latitude","Longitude"]
# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %%
for data in neighborhood_data:
    venue =data['name']
    venue_lat = data['location']['lat']
    venue_lon = data['location']['lng']
    neighborhoods = neighborhoods.append({'Venue': venue,'Latitude': venue_lat,
                                          'Longitude': venue_lon}, ignore_index=True)

# %%
print(neighborhoods.head())
# Out:
#                                      Venue   Latitude  Longitude
# 0  The Shops & Restaurants at Hudson Yards  40.753684 -74.001954
# 1              Indian Egg Donors DGA, Inc.  40.787468 -73.955444
# 2                        Indian Restaurant  40.750366 -73.998138
# 3                            Indian Summer  40.805885 -73.947311
# 4                    Indian fast food cart  40.759469 -73.972256

# %% [markdown]
# **ETL**

# %% [markdown]
# Removing those restaurants with NAN values instead of names

# %%
neighborhoods.dropna(subset=["Venue"])
# Out:
#                                       Venue   Latitude  Longitude
# 0   The Shops & Restaurants at Hudson Yards  40.753684 -74.001954
# 1               Indian Egg Donors DGA, Inc.  40.787468 -73.955444
# 2                         Indian Restaurant  40.750366 -73.998138
# 3                             Indian Summer  40.805885 -73.947311
# 4                     Indian fast food cart  40.759469 -73.972256
# 5                    Mughlai Indian Cuisine  40.780206 -73.950088
# 6                               Indian Rugs  40.762081 -73.964542
# 7                             indian Temple  40.812111 -73.952270
# 8                         The Indian Hunter  40.770372 -73.973352
# 9                            Indian Tanpura  40.788515 -73.974405
# 10                       Indian Wells Beach  40.767668 -73.987535
# 11                     Indian Country Today  40.762195 -73.972728
# 12                 Indian Passport Services  40.756593 -73.966561
# 13              Spice Hut Indian Restaurant  40.789675 -73.942797
# 14                           Indian Proverb  40.753682 -73.975296
# 15                             Indian place  40.824770 -73.941243
# 16                 Indian Express - Midtown  40.758007 -73.980446
# 17                           The Indian Hut  40.754689 -73.998162
# 18                           Indian Express  40.828719 -73.938004
# 19                           Om Indian Food  40.792014 -73.945332
# 20     Indian-African Handicraft & Jewelery  40.745618 -73.986330
# 21          Indian Project - Broadway Bites  40.749850 -73.987908
# 22                            Indian Accent  40.764127 -73.978787
# 23                 Polash Indian restaurant  40.799745 -73.938747
# 24                     Anand Indian Cuisine  40.772261 -73.955041
# 25                          Swagatam Indian  40.778301 -73.977989
# 26                   Imli Urban Indian Food  40.761646 -73.960129
# 27                            Simply Indian  40.814467 -73.959276
# 28                    Jai Ho Indian cuisine  40.831680 -73.984966
# 29           Junaid Restaurants in Stockton  40.768582 -73.965977
# 30                    Mezzaluna Restaurants  40.771352 -73.959682
# 31                Silli Point Indian Fusion  40.821690 -73.990460
# 32                Nuff Niceness Restaurants  40.811935 -73.942722
# 33                  Jaipur's Indian Cuisine  40.757080 -73.967270
# 34                      Simon Indian Palace  40.760179 -73.965884
# 35                   Basmati Indian Cuisine  40.764156 -73.988087
# 36                 Baluchi's Indian Cuisine  40.757072 -73.968527
# 37                            Karahi indian  40.765665 -73.987562
# 38                 The Halal Indian Kitchen  40.764312 -73.991705
# 39                       Indian Project NYC  40.754293 -73.990272
# 40       Go Burger by BLT restaurants Group  40.764954 -73.981950
# 41                   Dallas BBQ Restaurants  40.757000 -73.989126
# 42                  New York Indian Council  40.749447 -73.945496
# 43                     Tadka Indian Cuisine  40.750866 -73.945854
# 44            Khodiar Indian/Taj Dehli Chat  40.752127 -73.985834
# 45                      deep Indian Kitchen  40.757681 -73.981809
# 46                      Wu Kong Restaurants  40.756531 -73.980591
# 47               Delicious Indian Food Cart  40.758493 -73.919255
# 48       Chhandayan Center for Indian Music  40.755241 -73.983144
# 49                     Raj's Indian Kitchen  40.749976 -73.939261

# %% [markdown]
# Replacing the NAN values for Restaurants coordinates in Manhattan dataset with Latitude and Longitude of the Manhattan,NY

# %%
neighborhoods["Latitude"].fillna(40.7896239, inplace = True) 
neighborhoods["Longitude"].fillna( 40.7896239,inplace=True)

# %% [markdown]
# Cleaned dataset after Feature Engineerin

# %%
print(neighborhoods.head())
# Out:
#                                      Venue   Latitude  Longitude
# 0  The Shops & Restaurants at Hudson Yards  40.753684 -74.001954
# 1              Indian Egg Donors DGA, Inc.  40.787468 -73.955444
# 2                        Indian Restaurant  40.750366 -73.998138
# 3                            Indian Summer  40.805885 -73.947311
# 4                    Indian fast food cart  40.759469 -73.972256

# %% [markdown]
# **Creating the Map for Manhattan Dataset**

# %%
import folium
# create map of Manhattan using latitude and longitude values
map_manhattan = folium.Map(location=[venue_lat, venue_lon], zoom_start=13)

# add markers to map
for lat, lng,venue in zip(neighborhoods['Latitude'],neighborhoods['Longitude'], neighborhoods['Venue']):
    label = '{}'.format(venue)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=5,
        parse_html=False).add_to(map_manhattan)  
    
map_manhattan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_209c51a5d09448b5894024a737e370e6%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_209c51a5d09448b5894024a737e370e6%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_209c51a5d09448b5894024a737e370e6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_209c51a5d09448b5894024a737e370e6%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B40.74997632892085%2C%20-73.93926056994543%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_8e43788c54d94d29ba53c30d22f28aea%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0 ...

# %% [markdown]
# Importing KMeans for Clustering of the Restaurants

# %%
import random 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans 
 
# %matplotlib inline

# %%
manhattan_cluster=neighborhoods.drop("Venue",axis=1)

# %% [markdown]
# **Using the Elbow Method to check the best Clusters for the dataset Clustering**

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 12)
    kmeans.fit(manhattan_cluster)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('value')
plt.show()
plt.savefig("graph.jpg")

# %%
k_means = KMeans( n_clusters = 4, n_init = 12)

# %%
# run k-means clustering
kmeans = KMeans(n_clusters=4, random_state=0).fit(manhattan_cluster)

k_means_labels = kmeans.labels_
k_means_label = pd.DataFrame({'Labels': k_means_labels})
labels=k_means_label.values
labels.size
# Out:
# 50

# %%
# add clustering labels
frames=[k_means_label,neighborhoods]
manhattan_merged=pd.concat([k_means_label,neighborhoods],axis=1,sort=True)

manhattan_merged.head()
# Out:
#    Labels                                    Venue   Latitude  Longitude
# 0       1  The Shops & Restaurants at Hudson Yards  40.753684 -74.001954
# 1       2              Indian Egg Donors DGA, Inc.  40.787468 -73.955444
# 2       1                        Indian Restaurant  40.750366 -73.998138
# 3       0                            Indian Summer  40.805885 -73.947311
# 4       1                    Indian fast food cart  40.759469 -73.972256

# %%
def generateBaseMap(default_location=[40.693943, -73.985880], default_zoom_start=12):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

# %%
base_map = generateBaseMap()

# %%
# create map
base_map.add_child(folium.ClickForMarker(popup='Potential Location'))
map_clusters = folium.Map(location=[venue_lat, venue_lon], zoom_start=12)
manhatt=[manhat_latitude,manhat_longitude]
# set color scheme for the clusters
rainbow = ["blue","red","green","orange"]

#add markers to the map

markers_colors = []
for lat, lon, veu, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Venue'], manhattan_merged['Labels']):
    label = folium.Popup(str(veu) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
        
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_cd1f70fc35a9451191686798a04677e6%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_cd1f70fc35a9451191686798a04677e6%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_cd1f70fc35a9451191686798a04677e6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_cd1f70fc35a9451191686798a04677e6%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B40.74997632892085%2C%20-73.93926056994543%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_9f4a56b2fae7458eafe342ca2630ef41%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0 ...

# %% [markdown]
# **Analysing the Clusters**

# %% [markdown]
# ***Cluster 0***

# %%
cluster0=manhattan_merged.loc[manhattan_merged["Labels"]==0].shape[0]
cluster0
# Out:
# 9

# %% [markdown]
# ***Cluster 1***

# %%
cluster1=manhattan_merged.loc[manhattan_merged["Labels"]==1].shape[0]
cluster1
# Out:
# 23

# %% [markdown]
# ***CLuster 2***

# %%
cluster2=manhattan_merged.loc[manhattan_merged["Labels"]==2].shape[0]
cluster2
# Out:
# 16

# %% [markdown]
# ***Cluster 3***

# %%
cluster3=manhattan_merged.loc[manhattan_merged["Labels"]==3].shape[0]
cluster3
# Out:
# 2

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(labels,histtype="bar")
plt.xlabel("Cluster number")
plt.ylabel("Number of Restaurants")
plt.title("Number of restaurants is each clusters")
plt.savefig("cluster_rest.jpg")

# %% [markdown]
# #**Observations**

# %% [markdown]
# Most of the Indian Restaurants are concentrated in the west of Manhattan , with the highest number in cluster 1 and moderate number in cluster 0. On the other hand, cluster 3 has very low number to totally no Indian restaurants in the neighborhoods. This represents a great opportunity and high potential areas to open new Indian Restaurants as there is very little to no competition from existing restaurants Meanwhile,restaurants in cluster 1 are likely suffering from intense competition due to oversupply and high concentration of restaurants. From another perspective, this also shows that the oversupply of indian restaurants mostly happened due to more Indians living in the premisies. Therefore, this project recommends the client to capitalize on these findings to open new Indian Restaurant in neighborhoods in cluster 3 with little to no competition. Clients with unique selling propositions to stand out from the competition can also open new Indian Restaurants in neighborhoods in cluster 0 with moderate competition. Lastly, clients are advised to avoid neighborhoods in cluster 1 which already have high concentration of Indian Restaurants and suffering from intense competition.
